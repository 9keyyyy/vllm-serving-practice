# %%
# !pip install vllm

# %%
import subprocess
import time
import requests

# 1. vLLM 서버 시작
print("🚀 vLLM 서버 시작 중...")
p = subprocess.Popen([
    "python", "-m", "vllm.entrypoints.openai.api_server",
    "--model", "microsoft/Phi-3-mini-4k-instruct",
    "--dtype", "half",
    "--max-model-len", "2048",
    "--max-num-seqs", "32",
    "--host", "0.0.0.0",
    "--port", "8000"
], stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)

# 2. 서버 준비 대기
print("⏳ 서버 준비 대기 중... (최대 10분)")
server_ready = False
for i in range(600):  # 10분 대기
    try:
        response = requests.get("http://localhost:8000/health", timeout=1)
        if response.status_code == 200:
            print("✅ vLLM 서버 준비 완료!")
            server_ready = True
            break
    except:
        if i % 15 == 0:
            print(f"   대기 중... ({i}초)")
        time.sleep(1)

if not server_ready:
    print("❌ 서버 시작 실패")
else:
    # 3. ngrok 설정
    print("\n🔧 ngrok 설치 및 설정 중...")
    import subprocess
    subprocess.run(["pip", "install", "--upgrade", "--force-reinstall", "pyngrok", "-q"])

    from pyngrok import ngrok
    ngrok.set_auth_token("363Kt4PFu0eeVY6CBCDdhcCbscE_8jNgijzsjARNwXYgJbZZ")
    public_url = ngrok.connect(8000)

    print(f"\n🎉 준비 완료!")
    print(f"🌐 공개 URL: {public_url}")
    print(f"📋 API 엔드포인트: {public_url}/v1/chat/completions")
# Out:
# 🚀 vLLM 서버 시작 중...
# ⏳ 서버 준비 대기 중... (최대 10분)
#    대기 중... (0초)
#    대기 중... (15초)
#    대기 중... (30초)
#    대기 중... (45초)
#    대기 중... (60초)
#    대기 중... (75초)
#    대기 중... (90초)
# ✅ vLLM 서버 준비 완료!
#
# 🔧 ngrok 설치 및 설정 중...
#
# 🎉 준비 완료!
# 🌐 공개 URL: NgrokTunnel: "https://sanguineous-unpensioning-lizzette.ngrok-free.dev" -> "http://localhost:8000"
# 📋 API 엔드포인트: NgrokTunnel: "https://sanguineous-unpensioning-lizzette.ngrok-free.dev" -> "http://localhost:8000"/v1/chat/completions

# %%
# # ngrok으로 외부 노출
# !pip install --upgrade --force-reinstall pyngrok
# from pyngrok import ngrok

# ngrok.set_auth_token("363Kt4PFu0eeVY6CBCDdhcCbscE_8jNgijzsjARNwXYgJbZZ")
# public_url = ngrok.connect(8000)
# print(f"vLLM URL: {public_url}")

# %%
# !python -m vllm.entrypoints.openai.api_server \
#     --model microsoft/Phi-3-mini-4k-instruct \
#     --dtype half \
#     --max-model-len 2048 \
#     --max-num-seqs 32 \
#     --host 0.0.0.0 \
#     --port 8000

# %%
# GPU 메모리 정리
import torch
torch.cuda.empty_cache()

# 확인
# !nvidia-smi
# Out:
# Thu Nov 27 12:16:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   46C    P8             12W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
